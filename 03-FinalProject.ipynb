# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report section Title & Abstract trhough Data Wrangling:
# - Each Developing  => -0.5 pts
# - Each Unsatisfactory/Missing => -1 pts
#
# For the report section Data Visualizations through Documentation and Written Communication:
# - Each Developing  => -1 pts
# - Each Unsatisfactory/Missing => -2 pts
#
# For the video:
# - Developing  => -1.5 pts
# - Unsatisfactory/Missing => -3 pts
#
# Until the score is 0
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Exellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail                                                                                                                                                                                                                                                   | All relevant data sources were referenced and described in terms of their key variables and size                                                                                                                                                              | Multiple data sources for each aspect of the project, All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs ot the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code                                                                                                                                                                           | Data are made tidy and clean, or are clearly demonstrated to be so from download                                                                                                                                                                              | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Ethics                                                                             | No effort or just says we have no ethical concerns                                                                                                                                                                                                                                                  | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                 | The ethical concerns described are appropriate and sufficiently                                                                                                                                                                                                                                                                     | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues                                                                                                                                                                                                          |
# | Data visualizations                                                                | No plots. Or most plots don't capture useful information, or their display of information is difficult to understand. Legends, labels, axes, titles, captions, etc of most plots may be poor or missing. Most figures are not referenced in the main text.                                          | Fewer than 3 relevant plots (irrelevant to the question plots do not count).  Or a few of the plots don't make sense or capture useful information. Legends, labels, axes, titles, captions, etc are illegible or inadequately describe the content in a few figures. Or a few figures are not referenced or explained inside the main text. | Plots almost all make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging.      | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | No analyses beyond EDA style explorations of the dataset. Or analyses presented do not help address the question/hypothesis. Or most of the analyses presented are not technically approriate (eg. using parametric methods for non-parametric data).                                              | Only one analysis beyond EDA. Or a few analyses presented do not address the question/hypothesis. Or a few of the analyses presented are not technically approriate                                                                                                                                                                  |  At least two analyses beyond EDA. That is, the project uses two different techniques (e.g., inference vs machine learning; or t-test vs regression; or entire dataset vs stratified) or two different proxies for the same concept are investigated.  Each analysis addressed the question/hypothesis and is technically approriate. | Many different analyses are used. Each analysis addressed an aspect of the question/hypothesis and is technically approriate. Perhaps they use multiple datasets, or do something else to go the extra mile and address the reliability of the results                                            |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing                                                                                                                                                                                | Properly recapitulates the results and provides context for them. Has a sense of the limitatins and ethical issues.                                                                                                                                           | Clearly recapitulates the results and provides context, including the literature/background Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfacory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                   | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3-5min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true                                                                                | Video just outside the 3-5min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true                                                                                                      | Video has good quality and is in within 3-5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                        | Video has high production quality and is in within 3-5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach)                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                      |                                                                                                                                                                                                                                                                                                                       More than 5 excellents on this rubric: +0.5 points                                                                                   |

# %% [markdown]
# # COGS 108 - A Correlative Study in Music and its Effect on Mental Health and Focus/Productivity
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://drive.google.com/file/d/1poAUr5BmFGlAS8vPnf0lSD2JT00xZFHe/view?usp=sharing
#
# ## Abstract
#
# This project investigates how music affects mental health and cognitive performance by analyzing two datasets: the Music x Mental Health (MxMH) Survey (735 respondents) and the Kiss-Linnell Go/No-Go task experiment (120 participants across 62,220 trials). We applied chi-square tests, linear regression, paired t-tests, and KNN/logistic regression classifiers to explore associations between music listening habits, genre preferences, and outcomes including anxiety, depression, insomnia, OCD, reaction time, mood, and arousal. Our results reveal that music has a statistically significant effect on subjective mood and arousal, but does not meaningfully alter measurable task performance. Among genre preferences, only depression showed a statistically significant association with favorite genre. These findings suggest that music's influence on the human mind is real but context-dependent, meaning it shapes how people feel more reliably than how they perform.

# %% [markdown]
# # Authors
#
# - Evan Chou: Project administration, Software
# - Samar Mahle: Analysis, Writing - original draft, Methodology
# - Anthony Borja: Data curation, Visualization
# - Timothy Caroll: Experimental investigation, Writing - review & editing
# - Ashmina Pimentel: Background research, Conceptualization

# %% [markdown]
# ## Research Question

# %% [markdown]
# Music is widely recognized as having meaningful effects on human emotion, cognition, and overall wellbeing. In this project, we aim to investigate **how music affects individuals with mental disorders, how it influences subjective productivity, and whether generalizable patterns emerge that describe music’s broader impact on the human mind**.
#
# Our dataset will be constructed from extensive survey responses, including features such as preferred genres, listening habits, subjective productivity levels, and mental‑health classifications. Using these variables, we will conduct both exploratory and inferential analyses to identify patterns, correlations, and potential causal relationships. Ultimately, we hope to determine whether specific musical characteristics or genre preferences can meaningfully inform our understanding of mental health and productivity at a population level.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The effect of music on the brain has long been studied. For generations, music has been enjoyed and created by diverse cultures. It connects people, it amplifies emotions, and it varies in style to appeal to a wide range of people[<sup>1</sup>](#fn1). Some also claim to prefer working alongside music rather than without it. However, music’s effect on productivity may depend on how it is used.  This analysis, therefore, focuses on which genre, if any, is most conducive to productivity.
#
# Positive correlations between mental health and music have been recorded across multiple studies. There is a general consensus that enjoyment of music can reduce mental stress, anxiety, and depression among other difficult conditions. For example, Australian researchers Melissa K. Weinberg and Dawn Joseph found that in their sample, subjective wellbeing for individuals who had higher engagement with music was higher than those without[<sup>3</sup>](#fn3). This finding reveals a positive relationship between music engagement and emotional wellbeing and suggests our findings should coincide with this trend. However, this leaves a gap in specificity, as the study does not distinguish between types of music.
#
# Prior work hints that cognitive performance may be enhanced by slow-tempo music[<sup>2</sup>](#fn2). In this study, participants were driving and performing attention-demanding tasks. Findings showed that when listening to slow music, they responded faster to stimuli than with brown noise, silence, or other energetic music[<sup>2</sup>](#fn2). These results suggest that soothing genres like jazz and lo-fi may be associated with improved performance compared to louder, more energetic ones such as metal and rock. The article, however, does introduce an important nuance where its findings conflict with other such research and music was found to instead impede performance[<sup>2</sup>](#fn2). Thus, the question of whether music affects performance may depend on the specific task being measured rather than productivity in general. Therefore, “productivity” must be more precisely defined when conducting data analysis.
#
# If we focus on the population of young adults aged 18-25, who regularly use music during daily activities, we can observe a similar phenomenon. In a study conducted on aproximately 100 college students, researchers found that music with lyrics impaired cognitive abilities[<sup>4</sup>](#fn4). This aligns with previous studies where music with more stimuli reduced focus. However, while students performed better on tasks with instrumental music than music with lyrics, they did not perform significantly better or worse than when in silence[<sup>4</sup>](#fn4). This suggests that while young adults should fare better with certain genres, these genres should not be recommended for enhanced performance overall. Rather, they should be recommended only in relation to other genres.
#
# Ultimately, prior research on the influence of music on the human mind suggests a largely positive impact. Music may provide relaxation, emotional expression, and relatability, which explains its use in practices such as music therapy. However, research on music and productivity remains more divided. Highly stimulating music appears to reduce focus in many cases, while calmer instrumental music often produces results similar to silence. Because enjoyment and performance are not identical concepts, we must carefully define how productivity and effectiveness are measured when analyzing music’s effects.
#
#
# <span id="fn1"><sup>1</sup> Psychiatry.org - The Transformative Power of Music in Mental Well-Being</span>\
# <span id="fn2"><sup>2</sup> What you listen to makes a difference: The impact of music on attention and well‐being - PMC</span>\
# <span id="fn3"><sup>3</sup> If you’re happy and you know it: Music engagement and subjective wellbeing - Melissa K. Weinberg, Dawn Joseph, 2017</span>\
# <span id="fn4"><sup>4</sup> Should We Turn off the Music? Music with Lyrics Interferes with Cognitive Tasks - PMC</span>

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# In this project we hypothesize that different music genres and their characteristics such as BPM and genres will affect productivity and mental health in a variety of ways. We predict that lower-intensity music (e.g., jazz, binaural beats, classical, acoustic, lo-fi) characterized by repeated beats and fewer vocals is generally associated with higher productivity among the subjects sampled in the studies we have chosen, with a constraint on subjects with ages 18-25. Though this relationship will likely vary depending on the task type (Writing, Reading, Studying, Coding), with high-intensity activity expected to benefit from higher-intensity music. Most available datasets measure subjective productivity and are not nuanced, thus we predict low-intensity music to show a stronger overall positive association over high-intensity music.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name: **Music x Mental Health Survey Results**
#   - Link to the dataset: **https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results**
#   - Number of observations: **736 subjects**
#   - Number of variables: **32 features**
#   - Description of the variables most relevant to this project: This dataset contains many variables, including Fav genre, BPM, listening Frequencies of each genre, and Hours per day, which can be used for any inferential analysis with other variables relating mental health, such as Anxiety, Depression, Insomnia, and OCD as this can relate factors of music and listening preferences to mental health.
#   - Descriptions of any shortcomings this dataset has with repsect to the project: One of the biggest shortcomings this dataset has is that it is purely categorical. This means that we cannot analyze and derive relationships from regression-based methods, meaning that we would have to view this from a categorical correlative study with one-hot encoding for any computational methods involved.
#
# - Dataset #2
#   - Dataset Name: **The role of mood and arousal in the effect of background music on attentional state and performance during a sustained attention task** *(For simplicity, we will call this the Kiss-Linnell Dataset after the authors)*
#   - Link to the dataset: **https://pmc.ncbi.nlm.nih.gov/articles/PMC11045806/#notes2**
#   - Number of observations: **220 subjects across 2 experiments**
#   - Number of variables: **11 features**
#   - Description of the variables most relevant to this project: This dataset contains important variables such as Thought probe, Arousal, and Mood, which can be used for analysis with Reaction time. These are the main variables we will be analyzing in our study, as reaction time can correlate or associate with mental states and conditions.
#   - Descriptions of any shortcomings this dataset has with repsect to the project: Only 1/6 of the dataset is good data, due to the survey being conducted where every 1 out of 6 persons would be given the Thought probe, Arousal, and Mood questions, which are important for our analysis as it is the key mental state features for our investigation.

# %% [markdown]
# ### Dataset #1 - Music x Mental Health Dataset
#
# The important metrics are age measured in years, hours per day, frequencies measured by a subjective choice from Never to Very Frequently, favorite genre measured in object-type choices of Latin, Rock, etc., and Axneity, Depression, and Insomnia measured on a subjective scale from 1-10. For this scale, if a subject has a number greater than 5, they believe that they most likely go through that specific mental health condition, while subjects with lower number rankings believe that they do not go through that state.
#
# Some important concerns are on how the data in the study was collected. Although the sampling population was able to not be constricted by posting the Google Form survey on social media platforms and advertisements at public locations, The "Harder" questions such as BPM were left optional. This means that we have significantly less data to use for the BPM variable, and only the subjects that answered the BPM question were probably familiar with music characteristics already as a musician, composer, or instrumentalist.

# %%
### RAW DATA DESCRIPTION

import pandas as pd

df = pd.read_csv("data/00-raw/BNF_Dataset/background_noise_focus_dataset.csv")
print(df.head())
print("!! This dataset is tidy as each case study is in its own separate row, and each variable is in its own column.")

# Dataset Shape
print("!! The dataset has " + str(df.shape[0]) + " rows, and " + str(len(df.columns)) + " columns.")

# NaNs in Dataset
print("NaNs per colum:\n", df.isnull().sum())
print("\nTotal NaNs in dataset:", df.isnull().sum().sum())
print("!! We can see that there is no null values, which means that this dataset is also clean.")
# Out:
#    participant_id  age           role task_type background_noise_type  \
# 0               1   44        Student   Writing         Traffic Noise
# 1               2   30        Student   Writing               Silence
# 2               3   23  Remote Worker   Reading               Silence
# 3               4   36   Professional   Writing     Songs with Lyrics
# 4               5   34  Remote Worker  Studying         Traffic Noise
#
#    noise_volume_level  focus_duration_minutes  perceived_focus_score  \
# 0                   8                      98                      5
# 1                   9                      31                      3
# 2                   4                      39                      9
# 3                   1                      93                      4
# 4                   1                      94                      6
#
#    task_completion_quality  mental_fatigue_after_task
# 0                        5                          1
# ...

# %% [markdown]
# For more deails on the code and how the data was cleaned and wrangled, please check `modules/cleaning_scripts/clean_mxmh.py` and `modules/cleaning_scripts/encode_mxmh.py` for numerical encoding of categorical features. In the code cell below, we import both functions to clean, encode, and save the processed datasets.

# %%
### DATA WRANGLING/CLEANING
from modules.cleaning_scripts.clean_mxmh import clean_mxmh
from modules.cleaning_scripts.encode_mxmh import encode_mxmh

clean_mxmh()
encode_mxmh()
# Out:
# Dropped 1 rows with missing Age values.
# Filled 1 missing values in Primary streaming service with 'Spotify'.
# Filled 3 missing values in While working with 'Yes'.
# Filled 4 missing values in Instrumentalist with 'No'.
# Filled 1 missing values in Composer with 'No'.
# Filled 4 missing values in Foreign languages with 'Unknown'.
# Saved cleaned dataset to data\01-interim\MxMH_Survey_cleaned.csv
# Loaded data: 735 rows, 33 columns
# Label encoded 4 binary columns.
# Ordinal encoded 16 frequency columns.
# One-hot encoded 3 categorical columns.
# Saved encoded data to data\02-processed\MxMH_Survey_encoded.csv
# Saved encoding mappings to data\02-processed\encoding_mappings.json

# %% [markdown]
# ### Dataset #2 - Kiss-Linnell Dataset
#
# The important features are Reaction time measured in seconds (decimal places being milliseconds), Thought probe measured from 1-4, Arousal measured from 1-5, and Mood measured from 1-5. The numeric scaled features are self-reported by each participant who was chosen to answer those questions in the study, where for example, an arousal choice of 1 means not aroused and an arousal choice of 5 means very aroused.
#
# The main concern we have with this dataset again is the number of valid entries to the dataset after cleaning, where we are only getting 1/6 of the data that is in the dataset. This shortcoming may not be generalizable across different populations, which means we will have to analyze carefully and ensure that we are keeping a broad analysis on reaction time vs. mental health. Furthermore, this dataset does not include the age of the participants, so we will be unable to filter age groups 20-22 as we indicated in our hypothesis. As such, we will continue analyzing the dataset but generalize it to all age groups as the study does not list how age groups were chosen.

# %%
### RAW DATA DESCRIPTION

import pandas as pd

df = pd.read_excel("data/00-raw/Kiss_Linnell_Dataset/Experiment 1/Raw data.xlsx")
print(df.head())
print("!! This Experiment 1 dataset is not tidy as each case study has several roles for different reaction times, but each variable is in its own column.")

# Dataset Shape
print("!! The dataset has " + str(df.shape[0]) + " rows, and " + str(len(df.columns)) + " columns.")

# NaNs in Dataset
print("NaNs per colum:\n", df.isnull().sum())
print("\nTotal NaNs in dataset:", df.isnull().sum().sum())
print("!! We can see that there are lots of null values, but we can clean out the entries that did not answer Though probe, Arousal, and Mood questions, as those are our selected sampling population from the survey.")
# Out:
#    ID  Reaction time  ...  Music-present  presentation order
# 0   1       0.358835  ...           True                True
# 1   1       0.545465  ...           True                True
# 2   1       0.425985  ...           True                True
# 3   1       0.472115  ...           True                True
# 4   1       0.623765  ...           True                True
#
# [5 rows x 10 columns]
# !! This Experiment 1 dataset is not tidy as each case study has several roles for different reaction times, but each variable is in its own column.
# !! The dataset has 36040 rows, and 10 columns.
# NaNs per colum:
#  ID                        0
# Reaction time           929
# No-go trial           32860
# Thought probe         29680
# Arousal               29680
# Mood                  29680
# trial number              0
# block number              0
# Music-present             0
# presentation order        0
# dtype: int64
#
# Total NaNs in dataset: 122829
# ...

# %% [markdown]
# For more details on the code and how the data was cleaned and wrangled, please check `modules/cleaning_scripts/clean_kl.py`. In the code cell below, we import the function from this script to clean and save the data.

# %%
### DATA WRANGLING/CLEANING
from modules.cleaning_scripts.clean_kl import clean_kl

clean_kl()
# Out:
# Saved cleaned dataset to data\01-interim\KL_Dataset_cleaned.csv

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# **NOTE: For readability, you may see the code responsible for data visualizations in `02-EDACheckpoint.ipynb`. We also only selected certain meaningful EDA to display in this notebook.**

# %% [markdown]
# #### MxMH Dataset Stats
#
# Before conducting any analysis, we first examine the basic statistical properties of our dataset using `df.describe()`. The dataset contains 735 entries across key features including Age, Hours per day, BPM, and four self-reported mental health scores (Anxiety, Depression, Insomnia, OCD), each rated on a 0–10 scale.
#
# The sample skews towards younger ages, with a median age of 21 and a range of 10–89, suggesting a largely self-selected, younger demographic that should be kept in mind when generalizing findings. That is why we continue analyzing only participants between the ages of 20-22.
#
# Mental health scores behave as expected, all bounded between 0 and 10, with Anxiety reporting the highest median score (6.0) and OCD the lowest (2.0), consistent with patterns observed later in the heatmap analysis.
#
# The most notable data quality concern is the BPM column, where the mean (~1.59 million) and maximum (1 billion) are clearly faulty. Real BPM values should fall roughly between 60 and 200 BPM. The quartile values (100, 120, 144) confirm that the cleaned dataset is mostly valid, but a small number of extreme outliers are heavily affecting the summary statistics. These outliers were filtered prior to any analysis involving BPM.

# %%
import pandas as pd
CLEANED_FILE_PATH = "data/01-interim/MxMH_Survey_cleaned.csv"
cleaned_df = pd.read_csv(CLEANED_FILE_PATH)
cleaned_df.describe()
# Out:
#               Age  Hours per day           BPM     Anxiety  Depression  \
# count  735.000000     735.000000  6.290000e+02  735.000000  735.000000
# mean    25.206803       3.573537  1.589948e+06    5.833333    4.798639
# std     12.054970       3.030187  3.987261e+07    2.792515    3.030206
# min     10.000000       0.000000  0.000000e+00    0.000000    0.000000
# 25%     18.000000       2.000000  1.000000e+02    4.000000    2.000000
# 50%     21.000000       3.000000  1.200000e+02    6.000000    5.000000
# 75%     28.000000       5.000000  1.440000e+02    8.000000    7.000000
# max     89.000000      24.000000  1.000000e+09   10.000000   10.000000
#
#          Insomnia         OCD
# count  735.000000  735.000000
# mean     3.740816    2.631293
# std      3.090126    2.839383
# min      0.000000    0.000000
# 25%      1.000000    0.000000
# 50%      3.000000    2.000000
# 75%      6.000000    4.500000
# max     10.000000   10.000000

# %% [markdown]
# #### KDE Visualization for Disorder Severity Scores
#
# Here we can see that most people reported moderate to high scores of anxiety and low scores of OCD. None of the distributions are normal and depression in specific shows a high peak at around 6.5-7 and another slight peak at 2. Then, insomnia is right skewed with a slow drop off meaning more variability. This coincides with what we found with df.describe(). Given the high peaks in the other categories, we can expect that a linear regression model for these will be limited in the trends it shows.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("results/kde_mxmh.png")
plt.imshow(img)
plt.axis('off')  # Hide axis ticks
plt.show()

# %% [markdown]
# #### Chi-square test of association between patients' favorite genre and mental health conditions
#
# Based on the results of the p-values for each association in the chi-square test below, we can see that depression is the only significant finding with a p-value of 0.031, below the standard α = 0.05 threshold for statistical significance. This means that the distribution of favorite genres differs meaningfully between people who report depression and those who don't.
#
# However, because its Cramer's V value (for effect size) is 0.19, it can be inferred that although the association between Depression and favorite genre is statistically significant, the strength of the relationship is modest in which genre explains a small portion of variance in depression presence.
#
# Ultimately, the chi-square test on these features tell us that there is an association between Depression and favorite genre, but it does not prove that there is any causality between the features. It is also worth noting that with four simultaneous tests at α = 0.05, there is approximately a 19% chance of at least one false positive occurring by chance alone, meaning the Depression result should be interpreted with some caution.

# %%
import pandas as pd
from math import sqrt
from scipy.stats import chi2_contingency

CLEANED_FILE_PATH = "data/01-interim/MxMH_Survey_cleaned.csv"
ENCODED_FILE_PATH = "data/02-processed/MxMH_Survey_encoded.csv"
encoded_df = pd.read_csv(ENCODED_FILE_PATH)

fav_df = pd.read_csv(CLEANED_FILE_PATH)
mh_cols_local = [c for c in ['Anxiety', 'Depression', 'Insomnia', 'OCD'] if c in fav_df.columns]
for c in mh_cols_local:
    fav_df[c] = pd.to_numeric(fav_df[c], errors='coerce')
    fav_df[c + '_present'] = (fav_df[c] > 0).astype(int)
mh_cols_local = [c for c in ['Anxiety', 'Depression', 'Insomnia', 'OCD'] if c in fav_df.columns]
genre_col = 'Fav genre'

chi_rows = []
for mh in mh_cols_local:
    present_col = mh + '_present'
    table = pd.crosstab(fav_df[genre_col], fav_df[present_col])
    chi2, p, dof, expected = chi2_contingency(table)
    n_obs = table.to_numpy().sum()
    cramer_v = sqrt(chi2 / (n_obs * min(table.shape[0] - 1, table.shape[1] - 1)))
    chi_rows.append({
        'condition': mh,
        'chi2': chi2,
        'p_value': p,
        'cramers_v': cramer_v,
        'dof': dof,
    })

chi_df = pd.DataFrame(chi_rows).sort_values('p_value')
print('\nChi-square association between favorite genre and mental-health presence:')
print(chi_df.to_string(index=False))
# Out:
# Chi-square association between favorite genre and mental-health presence:
#  condition      chi2  p_value  cramers_v  dof
# Depression 26.786716 0.030523   0.190904   15
#    Anxiety 24.681034 0.054395   0.183247   15
#   Insomnia 19.726530 0.182676   0.163826   15
#        OCD 12.339155 0.653197   0.129568   15

# %% [markdown]
# #### Heatmap of mean mental health scores by favorite genre
#
# To analyze mean mental health scores across genres and conditions, we visualize a heatmap with favorite genre on the y-axis and mental health condition on the x-axis. The color scale ranges from light yellow (lower mean scores) to dark blue (higher mean scores).
#
# The most immediately visible pattern is that Anxiety scores are consistently the highest across all genres, with Folk listeners reporting the highest mean anxiety (6.57) and R&B the lowest (5.17). Depression scores follow a similar but slightly lower pattern, with Hip hop (5.88) and Rock (5.24) standing out.
#
# Insomnia and OCD scores are notably lower across the board, with OCD in particular showing the lightest colors throughout, suggesting that on average, respondents scored lower on OCD regardless of genre preference. This aligns with the chi-square result showing no significant association between genre and OCD.
#
# Metal listeners show a relatively elevated Insomnia score (4.56) compared to other genres, which is a subtle but interesting pattern worth noting. Overall, the heatmap suggests that genre groups differ more meaningfully on Anxiety and Depression than on Insomnia or OCD

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("results/heat_mxmh.png")
plt.imshow(img)
plt.axis('off')  # Hide axis ticks
plt.show()

# %% [markdown]
# #### Compare General Listening to Mental Health Severity with Linear Regression Models
#
# When comparing the hours a day someone listens to music with their perceived mental health scores, we can see a positive slope in all four graphs.
#
# Further detail into the slope, intercept, R-squared value, and p-values of these graphs reveal that we can attribute some association for depression, insomnia, and OCD albeit weak. The p-value for Hours Listened v. Anxiety was the only one larger than the preferred 0.05 score thus its slope was statistically insignificant. Additionally, the R-squared values for all graphs was low, pointing out that the predicibility of someone's mental health scores have much to do with variables outside of music enjoyment.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread("results/lr_mxmh.png")
plt.imshow(img)
plt.axis('off')  # Hide axis ticks
plt.show()

CLEANED_FILE_PATH = "data/01-interim/MxMH_Survey_cleaned.csv"
df = pd.read_csv(CLEANED_FILE_PATH)

mh_cols = ['Anxiety', 'Depression', 'Insomnia', 'OCD']

from scipy.stats import linregress

print(f"{'Disorder':<12} | {'Slope (m)':<10} | {'Intercept (b)':<14} | {'R-squared':<10} | {'P-value':<8}")
print("-" * 65)

for disorder in mh_cols:
    if disorder in df.columns:
        clean_data = df[['Hours per day', disorder]].dropna()
        
        # X is independent (Hours), Y is dependent (Disorder Score)
        x = clean_data['Hours per day']
        y = clean_data[disorder]
        
        # Calculate the linear regression metrics
        slope, intercept, r_value, p_value, std_err = linregress(x, y)
        
        print(f"{disorder:<12} | {slope:<10.4f} | {intercept:<14.4f} | {r_value**2:<10.4f} | {p_value:<8.4f}")
# Out:
# Disorder     | Slope (m)  | Intercept (b)  | R-squared  | P-value
# -----------------------------------------------------------------
# Anxiety      | 0.0458     | 5.6698         | 0.0025     | 0.1787
# Depression   | 0.1104     | 4.4041         | 0.0122     | 0.0027
# Insomnia     | 0.1445     | 3.2244         | 0.0201     | 0.0001
# OCD          | 0.1118     | 2.2317         | 0.0142     | 0.0012

# %% [markdown]
# #### Kiss-Linnell Dataset Stats
#
# Before conducting analysis on the Kiss-Linnell dataset (titled "The role of mood and arousal in the effect of background music on attentional state and performance during a sustained attention task), we first examine its basic statistical properties using df.describe(). The dataset contains 62,220 trials spanning 120 participants across 2 experiments, with up to 5 blocks of 34 trials each, reflecting a structured repeated-measures design consistent with a Go/No-Go task paradigm.
#
# Reaction time shows a median of ~454ms and a tight interquartile range (387–558ms), which is consistent with typical Go/No-Go response latencies. However, the maximum value of 265 seconds is suspicious, which likely representing a missed trial or recording artifact. This was filtered prior to any reaction time analysis.
#
# Thought probe, Arousal, and Mood are only populated for 10,980 of the 62,220 rows, which is expected given that probes were administered on a subset of trials rather than continuously. Thought probe responses range from 1-4, while Arousal and Mood are rated on a 1-5 scale, both with medians of 3, suggesting responses are roughly centered around the midpoint with no strong skew.
#
# The No-go trial column shows zero variance with a constant value of 1.0 across all entries, indicating it functions as a binary feature rather than a meaningful continuous variable. This column was excluded from quantitative analysis accordingly due to participants choosing to not go.
#
# Overall, the dataset is well-structured with two targeted data quality issues: the reaction time outlier and the No-go trial constant, both of which were addressed before proceeding with further analysis.

# %%
import pandas as pd

FILE_PATH = "data/01-interim/KL_Dataset_cleaned.csv"
df = pd.read_csv(FILE_PATH)
df.describe()
# Out:
#                  ID  Reaction time  No-go trial  Thought probe        Arousal  \
# count  62220.000000   60571.000000       5490.0    10980.000000  10980.000000
# mean      55.677596       0.563803          1.0        2.000364      2.928506
# std       33.355287       2.208816          0.0        0.809251      1.116368
# min        1.000000       0.000700          1.0        1.000000      1.000000
# 25%       27.000000       0.386500          1.0        1.000000      2.000000
# 50%       54.000000       0.454345          1.0        2.000000      3.000000
# 75%       85.000000       0.557725          1.0        2.000000      4.000000
# max      120.000000     265.032600          1.0        4.000000      5.000000
#
#                Mood  trial number  block number    experiment
# count  10980.000000  62220.000000  62220.000000  62220.000000
# mean       3.140346     17.500000      3.000000      1.420765
# std        0.994049      9.810787      1.414225      0.493686
# ...

# %% [markdown]
# #### Log Transformation of Reaction Time
#
# Reaction time is right-skewed due to a long tail of slow responses. A log transformation compresses that tail and pulls the distribution closer to normal, which helps downstream modeling and statistical tests that assume normality. We decided to use the feedback from the EDA Checkpoint in our analysis because of how outlier differences in milliseconds is not a large margin in the real world, and it is not reasonable to filter and drop those entries due to the small margin of difference.

# %%
rt = df['Reaction time'].dropna()
rt_positive = rt[rt > 0]
rt_log = np.log(rt_positive)

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

axes[0].hist(rt_positive, bins=80, color='steelblue', edgecolor='white')
axes[0].set_xlabel('Reaction Time (s)')
axes[0].set_ylabel('Count')
axes[0].set_title('Before: Reaction Time (raw)')

axes[1].hist(rt_log, bins=80, color='tomato', edgecolor='white')
axes[1].set_xlabel('log(Reaction Time)')
axes[1].set_ylabel('Count')
axes[1].set_title('After: log(Reaction Time)')

plt.tight_layout()
plt.show()

print(f"Raw  — skewness: {rt_positive.skew():.3f},  mean: {rt_positive.mean():.4f},  std: {rt_positive.std():.4f}")
print(f"Log  — skewness: {rt_log.skew():.3f},  mean: {rt_log.mean():.4f}, std: {rt_log.std():.4f}")
# Out:
# Raw  — skewness: 85.567,  mean: 0.5638,  std: 2.2088
# Log  — skewness: 0.279,  mean: -0.7330, std: 0.4258

# %% [markdown]
# #### T-Tests for Reaction time, Mood, Arousal, and Thought probe
#
# These are four t-tests done on each variable: Mood, Arousal, Thought Probe, and Reaction. We see that for our p-tests the results are meaningful for **Mood, Arousal,** and **Thought probe**. The p-tests results for Reaction time are very large, indicating it is not statistically significant.
#
# For t-test we see that it is extremely low for reaction time as well compared to other variables. Despite low variance in mean, we can conclude that for mood, arousal, and thought probe they were all affected by music trials while reaction time was not.

# %%
from scipy.stats import ttest_rel
import pandas as pd

FILE_PATH = "data/01-interim/KL_Dataset_cleaned.csv"
df = pd.read_csv(FILE_PATH)


variables = ['Reaction time', 'Mood', 'Arousal', 'Thought probe ']

for var in variables:
    # Optional: use cleaned reaction time only for Reaction time
    if var == 'Reaction time':
        temp_df = df[df['Reaction time'] < 10].copy()
    else:
        temp_df = df.copy()

    # Average each variable by participant and music condition
    summary = (
        temp_df
        .dropna(subset=[var])
        .groupby(['ID', 'Music-present'])[var]
        .mean()
        .reset_index()
    )

    # Make one column for No Music and one for Music
    wide = summary.pivot(
        index='ID',
        columns='Music-present',
        values=var
    )

    wide.columns = ['No_Music', 'Music']
    wide = wide.dropna()

    # Paired t-test
    result = ttest_rel(
        wide['Music'],
        wide['No_Music']
    )

    print(var)
    print(f"No Music mean: {wide['No_Music'].mean():.3f}")
    print(f"Music mean: {wide['Music'].mean():.3f}")
    print(f"t({result.df}) = {result.statistic:.3f}, p = {result.pvalue:.3f}")
    print("\n")
# Out:
# Reaction time
# No Music mean: 0.551
# Music mean: 0.537
# t(114) = -0.799, p = 0.426
#
#
# Mood
# No Music mean: 2.890
# Music mean: 3.356
# t(114) = 7.964, p = 0.000
#
#
# Arousal
# No Music mean: 2.814
# Music mean: 3.002
# t(114) = 3.919, p = 0.000
#
#
# Thought probe
# No Music mean: 1.949
# Music mean: 2.043
# t(114) = 2.791, p = 0.006

# %% [markdown]
# #### KNN and Logistic Regression Classifiers using All Features
#
# We trained two classifiers: a k-Nearest Neighbors (KNN) with the best `k` selected by 5-fold cross-validation, and a Logistic Regression (LR), to predict whether music was present, using all four features: log(Reaction Time), Mood, Arousal, and Thought Probe.
#
# KNN and LR both achieve roughly 55–58% accuracy. The confusion matrices show that the models correctly classify slightly more than half of all trials in each condition, but the error rate remains high (roughly 40–45% of trials misclassified). This is expected because if music strongly determined all four features, the classifier would score much higher.
#
# The LR coefficient plot is the most informative output. It shows which features the model leans on most. Features with large positive coefficients push toward predicting "Music present", while large negative coefficients push toward "No Music." Mood and Arousal typically dominate, while log(RT) and Thought Probe contribute little, which is consistent with the t-test results above.
#
# The ROC curves confirm this: AUC values above 0.50 mean the model is doing something useful, but AUC well below 0.80 means it is far from a reliable predictor.

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, RocCurveDisplay
import numpy as np

# Build model dataframe — use log(RT) instead of raw RT to reduce skew influence on KNN
model_df = df[['Reaction time', 'Mood', 'Arousal', 'Thought probe ', 'Music-present']].dropna().copy()
model_df = model_df[model_df['Reaction time'] > 0]
model_df['log_RT'] = np.log(model_df['Reaction time'])

X = model_df[['log_RT', 'Mood', 'Arousal', 'Thought probe ']]
y = model_df['Music-present']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)

# Tune KNN: search k in [3, 5, 7, 9, 11, 15, 21]
knn_grid = GridSearchCV(
    Pipeline([('scaler', StandardScaler()), ('knn', KNeighborsClassifier())]),
    param_grid={'knn__n_neighbors': [3, 5, 7, 9, 11, 15, 21]},
    cv=5, scoring='accuracy'
)
knn_grid.fit(X_train, y_train)
best_k = knn_grid.best_params_['knn__n_neighbors']
print(f"Best k (5-fold CV): {best_k}")

# Logistic Regression
lr_pipe = Pipeline([('scaler', StandardScaler()), ('lr', LogisticRegression(max_iter=1000))])
lr_pipe.fit(X_train, y_train)

img = mpimg.imread("results/ml_kl.png")
plt.imshow(img)
plt.axis('off')  # Hide axis ticks
plt.show()

img = mpimg.imread("results/roc_kl.png")
plt.imshow(img)
plt.axis('off')  # Hide axis ticks
plt.show()

img = mpimg.imread("results/lrfi_kl.png")
plt.imshow(img)
plt.axis('off')  # Hide axis ticks
plt.show()
# Out:
# Best k (5-fold CV): 21

# %% [markdown]
# ### First Analysis You Did - Give it a better title
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model
#
# **NOTE** The final report should not be overly long.  If this analysis step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any analysis you later decided was unecessary side quest before checking in for the final hand in
# 2) if the code to do an analysis is very long (in either lines or in time to compute) put it in a different file.  In that file make write out results of analysis into `results/` and reload the results here instead of recalculating it. And make a statement here like "To see the code responsible for analyses see `path/to/some-file-name.ipynb_or.py`."

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ### Second Analysis You Did - Give it a better title
#
# Some more words and stuff.  Remember notebooks work best if you interleave the code that generates a result with properly annotate figures and text that puts these results into context.  Every project will be different here... but some examples of analyses are: inferential statistics where you calculate p-values (like a t-test or a Monte Carlo simulation), regression models, or a machine learning model

# %%
## YOUR CODE HERE
## FEEL FREE TO ADD MULTIPLE CELLS PER SECTION

# %% [markdown]
# ## Ethics
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > We will be using human subject's information and data we will have opt-in explicitly showing particiants  hwo their data will be used withotu infringing upon the data itself.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Yes, we have aknowledged how the data we uyse may be skewed towards a 18-25 age group, we will aim towards broader data sets. In the event that we cannot do so, we plan to shrink the scope of our claims in order to preven false blanket statements that do not properly encapsulate populations we would be discussing.
#
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > No public accounts, no scraping!
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > Race and gender will not be a part of our data sets, and we will not be webscraping!
#
# ### B. Data Storage
#
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > Publicly available to begin with, stored locally. In the unlinkely case we release a survey, we will maintain anonymity to a degree where deleting the data will be of little consequence.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > In the unlikely case we release a survey, participants will be able to opt out. We will use informed consent to have parties acknowledge the fact that their data will be used in said way.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > Informed consent and anonymity will give subjects (from our own survey) the autonomy to choose whether or not we will use their data.Because of the anonymous and non PII nature of the data we are not concerned about deleting local data, however we are open to changing this in the future if needed.
#
#
# ### C. Analysis
#
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
#  > Look at the datasets and determine if a professional partook in the collection process. If needded contact one, however our project is not very
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > Yes we will consider the implications of subscription based services and other variables and choosing not to include them within our datasets, additionally anonymity will prevent some levels of bias
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > We will work within our full ability to
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > We are not using PII and we plan to use anonymous voluntary data.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > We will we be documenting to the best of our abilities.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > We will take this into consideration and actively work to make sure that our model is as robust transparent with the intention to serve the public first.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > We plan to do this thoroughly.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We are still within the planning stage and have not had to implement metric selection, but when the time comes we will ensure that this is considered by multiple group members, experts and outside parties.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > We are still within the planning stage and have not had to implement the model, but when the time comes we will ensure that this is considered by multiple group members, experts and outside parties.
#
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We are still within the planning stage and have not had to consider the shortcomings, limitations, and biases of the model to relevant stakeholders.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# > We are not publicy deploying this project, we intend for this to be purely inferential and exploratory. As a result it will be private to our group.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > We are not publicy deploying this project, we intend for this to be purely inferential and exploratory. As a result it will be private to our group.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# > We are not publicy deploying this project, we intend for this to be purely inferential and exploratory. As a result it will be private to our group. We will actively make the decision to put the general public first.
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > We are not publicy deploying this project, we intend for this to be purely inferential and exploratory. As a result it will be private to our group. We will actively make the decision to put the general public first.

# %% [markdown]
# ## Discusison and Conclusion
#
# We set out to find relationships between music genres, mental health, and the productivity of young people. Any trends revealed through this study may help identify ways music could be used as a tool to support student wellbeing and productivity. We used the dataset “Music x Mental Health Survey Results” conducted by Catherine Rasgaitis and uploaded on Kaggle for the first part of our question, and “The role of mood and arousal in the effect of background music on attentional state and performance during a sustained attention task” dataset from Luca Kiss and Karina J Linnell’s scientific research into the same question.
#
# Looking into the first dataset, we find that most participants reported moderate to high levels of anxiety and low levels of OCD which will be important later when analyzing the limitations in our results. When only focusing on hours listening to music per day, we find a statistically significant positive correlation between depression, OCD, and insomnia severity and listening hours. Anxiety was the only disorder that did not show any meaningful association with listening hours. While relatively weak, these correlations reveal a notable tendency to have higher mental health disorder severities the more hours spent listening to music. From our prior research, people should have better wellbeing with more music engagement. At face value, our results are too inconclusive to directly support this well rounded theory. However, taking into account that music as a form of therapy is largely accepted given its soothing effects, one possible interpretation of this result is that people experiencing higher levels of depression, OCD, and insomnia may engage with music more frequently as a form of self-regulation. Given the cross-sectional nature and limitations of our dataset, however, we cannot determine the direction of this relationship or establish causation. Therefore, this interpretation remains speculative and should be considered alongside existing literature supporting the therapeutic benefits of music.
#
# Further narrowing our focus into specific genres we find valuable patterns among the genres Folk, Classical, Hip Hop, Rock and Metal with anxiety, depression and insomnia. This is from analyzing the mean scores for the disorders for every group of people who had the same favorite genre. Given the limited presence of OCD within respondents, we could not find a meaningful link between any favorite genre and OCD severity. Anxiety scores were generally elevated across all favorite genres, though respondents who preferred Folk music reported the highest mean anxiety scores while Classical listeners reported the lowest. With depression, Hip Hop and Rock reported the highest mean scores. For insomnia, Metal was the highest. Moreover, using a chi-square test on favorite genres and mental health conditions tell us that there is an association between depression and favorite genres, although by a small margin. From these results, we observe a small tendency for certain genres, including Hip Hop, Rock, and Metal, to be associated with higher average mental health severity scores, as we predicted would happen in our hypothesis. However, the observations are relatively weak and our data is limited since it does not include outside factors affecting mental health other than music choice. Thus, we cannot draw any reasonable conclusion whether these specific genres help or inhibit mental health wellbeing while we have evidence of slight correlation with higher mean scores.
#
# Bpms ?
#
# Paragraphs on the other dataset. (still in progress)
#
# Unfortunately, our results were greatly limited by the categorical and self-evaluated nature of the questions participants responded to. Additionally, the respondent population was characterized by relatively high anxiety scores and relatively low OCD scores, limiting the variability available for analysis. In the end, the associations we found were not large and strong; they were pretty moderate and otherwise weak. We could have also only revealed the type of music people who are already dealing with these conditions would gravitate towards.
#
# Admittedly, we cannot derive actionable suggestions for which genre is best for mental health and productivity based solely on these numbers. Naturally, this is because the driving force behind mental health issues are more nuanced than can be exclusively predicted by an individual's listening habits. A more interesting observation concerns the distinction between perceived and measured effects. While many respondents reported that music improved their mental health, our analyses were not able to quantify the magnitude of those benefits directly. Nevertheless, while there exists a disparity, this response is not useless. There is a real world effect by which music improves and evolves mental health conditions, as shown in previous studies. While we cannot definitively recommend Classical music for anxiety or discourage Metal for insomnia, engaging with music altogether may be beneficial to your emotions and wellbeing. On the other hand/similarly, the other dataset conclusion.
