# %% [markdown]
# ## Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 10 points
#
# - Each Developing  => -2 pts
# - Each Unsatisfactory/Missing => -4 pts
#   - until the score is
#
# If students address the detailed feedback in a future checkpoint they will earn these points back
#
#
# |                  | Unsatisfactory                                                                                                                                                                                                    | Developing                                                                                                                                                                                              | Proficient                                     | Excellent                                                                                                                              |
# |------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------------|
# | Data relevance   | Did not have data relevant to their question. Or the datasets don't work together because there is no way to line them up against each other. If there are multiple datasets, most of them have this trouble | Data was only tangentially relevant to the question or a bad proxy for the question. If there are multiple datasets, some of them may be irrelevant or can't be easily combined.                       | All data sources are relevant to the question. | Multiple data sources for each aspect of the project. It's clear how the data supports the needs of the project.                         |
# | Data description | Dataset or its cleaning procedures are not described. If there are multiple datasets, most have this trouble                                                                                              | Data was not fully described. If there are multiple datasets, some of them are not fully described                                                                                                      | Data was fully described                       | The details of the data descriptions and perhaps some very basic EDA also make it clear how the data supports the needs of the project. |
# | Data wrangling   | Did not obtain data. They did not clean/tidy the data they obtained.  If there are multiple datasets, most have this trouble                                                                                 | Data was partially cleaned or tidied. Perhaps you struggled to verify that the data was clean because they did not present it well. If there are multiple datasets, some have this trouble | The data is cleaned and tidied.                | The data is spotless and they used tools to visualize the data cleanliness and you were convinced at first glance                      |

# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# - Evan Chou: Project administration, Software
# - Samar Mahle: Analysis, Writing - original draft, Methodology
# - Anthony Borja: Data curation, Visualization
# - Timothy Caroll: Experimental investigation, Writing - review & editing
# - Ashmina Pimentel: Background research, Conceptualization

# %% [markdown]
# ## Research Question

# %% [markdown]
# Music is widely recognized as having meaningful effects on human emotion, cognition, and overall wellbeing. In this project, we aim to investigate **how music affects individuals with mental disorders, how it influences subjective productivity, and whether generalizable patterns emerge that describe music’s broader impact on the human mind**.
#
# Our dataset will be constructed from extensive survey responses, including features such as preferred genres, listening habits, subjective productivity levels, and mental‑health classifications. Using these variables, we will conduct both exploratory and inferential analyses to identify patterns, correlations, and potential causal relationships. Ultimately, we hope to determine whether specific musical characteristics or genre preferences can meaningfully inform our understanding of mental health and productivity at a population level.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The effect of music on the brain has long been studied. For generations, music has been enjoyed and created by diverse cultures. It connects people, it amplifies emotions, and it varies in style to appeal to a wide range of people[<sup>1</sup>](#fn1). Some also claim to prefer working alongside music rather than without it. However, music’s effect on productivity may depend on how it is used.  This analysis, therefore, focuses on which genre, if any, is most conducive to productivity.
#
# Positive correlations between mental health and music have been recorded across multiple studies. There is a general consensus that enjoyment of music can reduce mental stress, anxiety, and depression among other difficult conditions. For example, Australian researchers Melissa K. Weinberg and Dawn Joseph found that in their sample, subjective wellbeing for individuals who had higher engagement with music was higher than those without[<sup>3</sup>](#fn3). This finding reveals a positive relationship between music engagement and emotional wellbeing and suggests our findings should coincide with this trend. However, this leaves a gap in specificity, as the study does not distinguish between types of music.
#
# Prior work hints that cognitive performance may be enhanced by slow-tempo music[<sup>2</sup>](#fn2). In this study, participants were driving and performing attention-demanding tasks. Findings showed that when listening to slow music, they responded faster to stimuli than with brown noise, silence, or other energetic music[<sup>2</sup>](#fn2). These results suggest that soothing genres like jazz and lo-fi may be associated with improved performance compared to louder, more energetic ones such as metal and rock. The article, however, does introduce an important nuance where its findings conflict with other such research and music was found to instead impede performance[<sup>2</sup>](#fn2). Thus, the question of whether music affects performance may depend on the specific task being measured rather than productivity in general. Therefore, “productivity” must be more precisely defined when conducting data analysis.
#
# If we focus on the population of young adults aged 18-25, who regularly use music during daily activities, we can observe a similar phenomenon. In a study conducted on aproximately 100 college students, researchers found that music with lyrics impaired cognitive abilities[<sup>4</sup>](#fn4). This aligns with previous studies where music with more stimuli reduced focus. However, while students performed better on tasks with instrumental music than music with lyrics, they did not perform significantly better or worse than when in silence[<sup>4</sup>](#fn4). This suggests that while young adults should fare better with certain genres, these genres should not be recommended for enhanced performance overall. Rather, they should be recommended only in relation to other genres.
#
# Ultimately, prior research on the influence of music on the human mind suggests a largely positive impact. Music may provide relaxation, emotional expression, and relatability, which explains its use in practices such as music therapy. However, research on music and productivity remains more divided. Highly stimulating music appears to reduce focus in many cases, while calmer instrumental music often produces results similar to silence. Because enjoyment and performance are not identical concepts, we must carefully define how productivity and effectiveness are measured when analyzing music’s effects.
#
#
# <span id="fn1"><sup>1</sup> Psychiatry.org - The Transformative Power of Music in Mental Well-Being</span>\
# <span id="fn2"><sup>2</sup> What you listen to makes a difference: The impact of music on attention and well‐being - PMC</span>\
# <span id="fn3"><sup>3</sup> If you’re happy and you know it: Music engagement and subjective wellbeing - Melissa K. Weinberg, Dawn Joseph, 2017</span>\
# <span id="fn4"><sup>4</sup> Should We Turn off the Music? Music with Lyrics Interferes with Cognitive Tasks - PMC</span>

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# In this project we hypothesize that different music genres and their characteristics such as BPM and genres will affect productivity and mental health in a variety of ways. We predict that lower-intensity music (e.g., jazz, binaural beats, classical, acoustic, lo-fi) characterized by repeated beats and fewer vocals is generally associated with higher productivity among the subjects sampled in the studies we have chosen, with a constraint on subjects with ages 18-25. Though this relationship will likely vary depending on the task type (Writing, Reading, Studying, Coding), with high-intensity activity expected to benefit from higher-intensity music. Most available datasets measure subjective productivity and are not nuanced, thus we predict low-intensity music to show a stronger overall positive association over high-intensity music.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# Instructions: REPLACE the contents of this cell with descriptions of your actual datasets.
#
# For each dataset include the following information
# - Dataset #1
#   - Dataset Name: **Music x Mental Health Survey Results**
#   - Link to the dataset: **https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results**
#   - Number of observations: **736 subjects**
#   - Number of variables: **32 features**
#   - Description of the variables most relevant to this project: This dataset contains many variables, including Fav genre, BPM, listening Frequencies of each genre, and Hours per day, which can be used for any inferential analysis with other variables relating mental health, such as Anxiety, Depression, Insomnia, and OCD as this can relate factors of music and listening preferences to mental health.
#   - Descriptions of any shortcomings this dataset has with repsect to the project: One of the biggest shortcomings this dataset has is that it is purely categorical. This means that we cannot analyze and derive relationships from regression-based methods, meaning that we would have to view this from a categorical correlative study with one-hot encoding for any computational methods involved.
# - Dataset #2 (if you have more than one!)
#   - Dataset Name: **Background Noise and Focus Dataset**
#   - Link to the dataset: **https://www.kaggle.com/datasets/prince7489/background-noise-and-focus-dataset?resource=download**
#   - Number of observations: **500 subjects**
#   - Number of variables: **9 features**
#   - Description of the variables most relevant to this project: This dataset contains many variables, including role, task_type, background_noise_type, and noise_volume_level, which can be used for any inferential analysis with focus_duration_minutes, task_completion, quality, etc. as this can relate factors of background noise to productivity and focus.
#   - Descriptions of any shortcomings this dataset has with repsect to the project: The dataset includes standardized ranking-based choices for perceived_focus_score, task_completion_quality, and mental_fatigue_after_task, which can be very subjective based on the participant themselves how they rank themselves in those choices.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# Setup code -- this only needs to be run once after cloning the repo!
# this code downloads the data from its source to the `data/00-raw/` directory
# if the data hasn't updated you don't need to do this again!

# if you don't already have these packages (you should!) uncomment this line
# %pip install requests tqdm

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/airline-safety/airline-safety.csv', 'filename':'airline-safety.csv'},
    { 'url': 'https://raw.githubusercontent.com/fivethirtyeight/data/refs/heads/master/bad-drivers/bad-drivers.csv', 'filename':'bad-drivers.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')

# %% [markdown]
# ### Dataset #1 - Music x Mental Health Dataset
#
# The important metrics are age measured in years, hours per day, frequencies measured by a subjective choice from Never to Very Frequently, favorite genre measured in object-type choices of Latin, Rock, etc., and Axneity, Depression, and Insomnia measured on a subjective scale from 1-10. For this scale, if a subject has a number greater than 5, they believe that they most likely go through that specific mental health condition, while subjects with lower number rankings believe that they do not go through that state.
#
# Some important concerns are on how the data in the study was collected. Although the sampling population was able to not be constricted by posting the Google Form survey on social media platforms and advertisements at public locations, The "Harder" questions such as BPM were left optional. This means that we have significantly less data to use for the BPM variable, and only the subjects that answered the BPM question were probably familiar with music characteristics already as a musician, composer, or instrumentalist.

# %%
import pandas as pd
from pathlib import Path

# Tidy Dataset
df = pd.read_csv("data/00-raw/MxMH_Survey/mxmh_survey_results.csv")
print(df.head())
print("!! This dataset is tidy as each case study is in its own separate row, and each variable is in its own column.")

# Dataset Shape
print("!! The dataset has " + str(df.shape[0]) + " rows, and " + str(len(df.columns)) + " columns.")

# NaNs in Dataset
print("NaNs per colum:\n", df.isnull().sum())
print("\nTotal NaNs in dataset:", df.isnull().sum().sum())
print("!! We can see that there is a lot of null values in the BPM variable. This is especially important as BPM might be one of our explored variables relating to the mental health of a subject.")

# Clean Data
# Age has one missing value, so we drop that row instead of imputing a potentially incorrect age.
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
rows_before_drop = len(df)
df = df.dropna(subset=["Age"]).copy()
print("Dropped", rows_before_drop - len(df), "rows with missing Age values.")

# Fill categorical missing values with the mode when there is a clear most common response.
fill_values = {
    "Primary streaming service": df["Primary streaming service"].mode(dropna=True).iloc[0],
    "While working": df["While working"].mode(dropna=True).iloc[0],
    "Instrumentalist": df["Instrumentalist"].mode(dropna=True).iloc[0],
    "Composer": df["Composer"].mode(dropna=True).iloc[0],
    "Foreign languages": "Unknown",
}

for column, fill_value in fill_values.items():
    missing_before = df[column].isna().sum()
    df[column] = df[column].fillna(fill_value)
    print(f"Filled {missing_before} missing values in {column} with {fill_value!r}.")

print("\nRemaining NaNs after cleaning:\n", df.isnull().sum()[df.isnull().sum() > 0])

# Save cleaned data for later use.
output_path = Path("data/02-processed/MxMH_Survey_cleaned.csv")
output_path.parent.mkdir(parents=True, exist_ok=True)
df.to_csv(output_path, index=False)
print(f"Saved cleaned dataset to {output_path}")
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %% [markdown]
# ### Dataset #2 - Background Noise and Focus Dataset
#
# The important metrics are noise_volume_level, perceived_focus_score, task_completion_quality, and mental_fatigue_after_task, all measured on a subjective ranking from 1-10. For example, if a subject ranks 5 or higher for noise_volume_level, they percieve a high noise level in the environment around them. Other metrics include focus_duration_minutes meausured in minutes, background_noise_type classified by Traffic Noise, Silence, Songs with Lyrics, etc., task_type classified by Writing, Reading, Studying, and Coding, role classified by Student, Remote Worker, Professional, etc., and age measured by year.
#
# The biggest concern with this dataset is with how the data was synthetically simulated. This means that any analysis we do with this dataset cannot be causal with real-world analytics, but it can serve as a base for future studies on background noise and focus/productivity. Luckily, the synthetic dataset is clean and tidy from the get-go, which means we can do inferential and exploratory analysis with the features accordingly without worrying about null values and such. Lastly, another con with synthetic data is where it was simulated from or what it was based on. The dataset does not detail how the data was collected, so we would not be exposed to apparent bias until we conduct further analysis.
#
# Because this dataset is inherently different from our first dataset (MxMH), we plan on using this to cross-reference our data analysis and hypothesis that music does affect our mental health, including mental conditions, focus, productivity, etc. as a whole case study on the topic. This means that we are not combining or aggregating the dataset together, but we will be conducting their individual analyses in parallel and then bring our observations and findings together to come to a conclusion about the research question answer.

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
# Tidy Dataset
df = pd.read_csv("data/00-raw/BNF_Dataset/background_noise_focus_dataset.csv")
print(df.head())
print("!! This dataset is tidy as each case study is in its own separate row, and each variable is in its own column.")

# Dataset Shape
print("!! The dataset has " + str(df.shape[0]) + " rows, and " + str(len(df.columns)) + " columns.")

# NaNs in Dataset
print("NaNs per colum:\n", df.isnull().sum())
print("\nTotal NaNs in dataset:", df.isnull().sum().sum())
print("!! We can see that there is no null values, which means that this dataset is also clean.")
# Out:
#    participant_id  age           role task_type background_noise_type  \
# 0               1   44        Student   Writing         Traffic Noise
# 1               2   30        Student   Writing               Silence
# 2               3   23  Remote Worker   Reading               Silence
# 3               4   36   Professional   Writing     Songs with Lyrics
# 4               5   34  Remote Worker  Studying         Traffic Noise
#
#    noise_volume_level  focus_duration_minutes  perceived_focus_score  \
# 0                   8                      98                      5
# 1                   9                      31                      3
# 2                   4                      39                      9
# 3                   1                      93                      4
# 4                   1                      94                      6
#
#    task_completion_quality  mental_fatigue_after_task
# 0                        5                          1
# ...

# %% [markdown]
# ## Ethics
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > We will be using human subject's information and data we will have opt-in explicitly showing particiants  hwo their data will be used withotu infringing upon the data itself.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Yes, we have aknowledged how the data we uyse may be skewed towards a 18-25 age group, we will aim towards broader data sets. In the event that we cannot do so, we plan to shrink the scope of our claims in order to preven false blanket statements that do not properly encapsulate populations we would be discussing.
#
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > No public accounts, no scraping!
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > Race and gender will not be a part of our data sets, and we will not be webscraping!
#
# ### B. Data Storage
#
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > Publicly available to begin with, stored locally. In the unlinkely case we release a survey, we will maintain anonymity to a degree where deleting the data will be of little consequence.
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > In the unlikely case we release a survey, participants will be able to opt out. We will use informed consent to have parties acknowledge the fact that their data will be used in said way.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > Informed consent and anonymity will give subjects (from our own survey) the autonomy to choose whether or not we will use their data.Because of the anonymous and non PII nature of the data we are not concerned about deleting local data, however we are open to changing this in the future if needed.
#
#
# ### C. Analysis
#
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
#  > Look at the datasets and determine if a professional partook in the collection process. If needded contact one, however our project is not very
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > Yes we will consider the implications of subscription based services and other variables and choosing not to include them within our datasets, additionally anonymity will prevent some levels of bias
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > We will work within our full ability to
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > We are not using PII and we plan to use anonymous voluntary data.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > We will we be documenting to the best of our abilities.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > We will take this into consideration and actively work to make sure that our model is as robust transparent with the intention to serve the public first.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > We plan to do this thoroughly.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We are still within the planning stage and have not had to implement metric selection, but when the time comes we will ensure that this is considered by multiple group members, experts and outside parties.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > We are still within the planning stage and have not had to implement the model, but when the time comes we will ensure that this is considered by multiple group members, experts and outside parties.
#
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We are still within the planning stage and have not had to consider the shortcomings, limitations, and biases of the model to relevant stakeholders.
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# > We are not publicy deploying this project, we intend for this to be purely inferential and exploratory. As a result it will be private to our group.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# > We are not publicy deploying this project, we intend for this to be purely inferential and exploratory. As a result it will be private to our group.
#
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# > We are not publicy deploying this project, we intend for this to be purely inferential and exploratory. As a result it will be private to our group. We will actively make the decision to put the general public first.
#
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > We are not publicy deploying this project, we intend for this to be purely inferential and exploratory. As a result it will be private to our group. We will actively make the decision to put the general public first.

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# * Maintain respectful and friendly attitudes towards one another.
# * Communicate all work and projected tasks ahead of time, and update all team members accordingly.
# * Suggest changes to another person's work. No directly changing their work or enforcing changes without permission.
# * Keep close communication on Discord. Members are expected to check frequently for updates.
# * Work on separate branches, and only member-specific branches. Members cannot work in another person's branch with their permission.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# | Meeting Date | Meeting Time | Completed Before Meeting | Discuss at Meeting |
# | --- | --- | --- | --- |
# | 5/1 | 1 PM | Read all sources and get a good idea on what kinds of features are in each dataset | Discuss timeline and proposal more thoroughly |
# | 5/5 | 10 AM | Download, import, and wrangle data and preprocess if necessary | Delegate tasks and split EDA work for different datasets with different people |
# | 5/8 | 1 PM | Do our individual EDA tasks and assignments | Check up with any issues and concerns with datasets or EDA |
# | 5/12 | 10 AM | Finalize wrangling/EDA and compile results | Start working on analysis of EDA and wrangling |
# | 5/15 | 1 PM | Have initial analysis done, including data visualizations and statistical inference | Bring all analysis together and discuss initial conclusions |
# | 5/19 | 10 AM | Explore and research machine learning methods, and edit current analysis | Present ML findings and updates for newer analysis |
# | 5/21 | 1 PM | Train and test ML modeling. Finetune and augment data for ML improvement | Present ML results, and discuss approach for explaining the results |
# | 5/28 | 1 PM | Finalize all methods and begin analysis | Discuss/edit analysis, results, conclusion, and discussion |
# | 6/2 | 10 AM | Complete analysis, draft results, conclusion, and discussion | Discuss/edit full project |
# | 6/5 | Before 11:59 PM | Finish up details and presentation/format of project | Turn in Final Project & Group Project Surveys |
